# %%
library(data.table)
library(ggplot2)

dat <- data.table(v1 = runif(100), v2 = runif(100))

head(dat)
# Out:
#   v1         v2
# 1 0.70394324 0.4541700
# 2 0.03718661 0.6233375
# 3 0.19307034 0.2298594
# 4 0.01565874 0.2291626
# 5 0.80231607 0.4516573
# 6 0.23310021 0.6820075

# %%
ggplot(dat, aes(x = v1, y = v2)) + geom_point()
# Out:
# plot without title
